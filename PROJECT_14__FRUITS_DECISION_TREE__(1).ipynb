# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv('/content/fruits.csv')

# %%
df
# Out:
#               color  sphericity  weight   label
# 0            Orange       0.947     120  Orange
# 1            Orange       0.917     125  Orange
# 2            Orange       0.923     110  Orange
# 3            Orange       0.916     123  Orange
# 4            Orange       0.943     124  Orange
# 5            Orange       0.911     130  Orange
# 6            Orange       0.903     135  Orange
# 7            Orange       0.918     105  Orange
# 8            Orange       0.914     132  Orange
# 9            Orange       0.936     127  Orange
# 10  Greenish yellow       0.829     133  Orange
# 11  Greenish yellow       0.875     134  Orange
# 12  Greenish yellow       0.859     110  Orange
# 13            Green       0.849     119  Orange
# 14            Green       0.868     106  Orange
# 15  Greenish yellow       0.884     113  Orange
# 16  Greenish yellow       0.872     108  Orange
# 17  Greenish yellow       0.823     132  Orange
# 18            Green       0.853     119  Orange
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   color       60 non-null     object
#  1   sphericity  60 non-null     float64
#  2   weight      60 non-null     int64
#  3   label       60 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.0+ KB

# %%
df.describe()
# Out:
#        sphericity      weight
# count   60.000000   60.000000
# mean     0.820583  142.750000
# std      0.067577   23.352585
# min      0.710000  101.000000
# 25%      0.767250  124.000000
# 50%      0.823000  143.000000
# 75%      0.870500  164.000000
# max      0.947000  184.000000

# %%
df.columns
# Out:
# Index(['color', 'sphericity', 'weight', 'label'], dtype='object')

# %%
df.shape
# Out:
# (60, 4)

# %%
df.size
# Out:
# 240

# %%
df.ndim
# Out:
# 2

# %%
df['color'].value_counts()
# Out:
# color
# Green              20
# Orange             10
# Greenish yellow    10
# Reddish yellow     10
# Red                10
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# color         0
# sphericity    0
# weight        0
# label         0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['label'].value_counts()
# Out:
# label
# Orange    30
# Apple     30
# Name: count, dtype: int64

# %%
X=df.iloc[:,:-1].values

# %%
X
# Out:
# array([['Orange', 0.947, 120],
#        ['Orange', 0.917, 125],
#        ['Orange', 0.923, 110],
#        ['Orange', 0.916, 123],
#        ['Orange', 0.943, 124],
#        ['Orange', 0.911, 130],
#        ['Orange', 0.903, 135],
#        ['Orange', 0.918, 105],
#        ['Orange', 0.914, 132],
#        ['Orange', 0.936, 127],
#        ['Greenish yellow', 0.829, 133],
#        ['Greenish yellow', 0.875, 134],
#        ['Greenish yellow', 0.859, 110],
#        ['Green', 0.849, 119],
#        ['Green', 0.868, 106],
#        ['Greenish yellow', 0.884, 113],
#        ['Greenish yellow', 0.872, 108],
#        ['Greenish yellow', 0.823, 132],
#        ['Green', 0.853, 119],
#        ['Green', 0.808, 143],
#        ['Greenish yellow', 0.838, 101],
#        ['Greenish yellow', 0.824, 149],
#        ['Green', 0.894, 136],
#        ['Green', 0.809, 141],
#        ['Greenish yellow', 0.88, 145],
#        ['Green', 0.834, 109],
#        ['Green', 0.809, 108],
#        ['Green', 0.86, 144],
# ...

# %%
Y=df.iloc[:,-1].values

# %%
Y
# Out:
# array(['Orange', 'Orange', 'Orange', 'Orange', 'Orange', 'Orange',
#        'Orange', 'Orange', 'Orange', 'Orange', 'Orange', 'Orange',
#        'Orange', 'Orange', 'Orange', 'Orange', 'Orange', 'Orange',
#        'Orange', 'Orange', 'Orange', 'Orange', 'Orange', 'Orange',
#        'Orange', 'Orange', 'Orange', 'Orange', 'Orange', 'Orange',
#        'Apple', 'Apple', 'Apple', 'Apple', 'Apple', 'Apple', 'Apple',
#        'Apple', 'Apple', 'Apple', 'Apple', 'Apple', 'Apple', 'Apple',
#        'Apple', 'Apple', 'Apple', 'Apple', 'Apple', 'Apple', 'Apple',
#        'Apple', 'Apple', 'Apple', 'Apple', 'Apple', 'Apple', 'Apple',
#        'Apple', 'Apple'], dtype=object)

# %%
df.label.value_counts()
# Out:
# label
# Orange    30
# Apple     30
# Name: count, dtype: int64

# %%
#  ye balanced dataset hai...
# task to identify whteher its apple nad oranges ?
# which fwature is best for ml model?
df.head(10)
# Out:
#     color  sphericity  weight   label
# 0  Orange       0.947     120  Orange
# 1  Orange       0.917     125  Orange
# 2  Orange       0.923     110  Orange
# 3  Orange       0.916     123  Orange
# 4  Orange       0.943     124  Orange
# 5  Orange       0.911     130  Orange
# 6  Orange       0.903     135  Orange
# 7  Orange       0.918     105  Orange
# 8  Orange       0.914     132  Orange
# 9  Orange       0.936     127  Orange

# %%
df.groupby(['color','label']).size()
# Out:
# color            label
# Green            Apple     10
#                  Orange    10
# Greenish yellow  Orange    10
# Orange           Orange    10
# Red              Apple     10
# Reddish yellow   Apple     10
# dtype: int64

# %%
df.groupby('label').describe()
# Out:
#        sphericity                                                             \
#             count      mean       std    min     25%     50%      75%    max
# label
# Apple        30.0  0.768133  0.042097  0.710  0.7285  0.7625  0.80250  0.845
# Orange       30.0  0.873033  0.042740  0.808  0.8350  0.8710  0.91325  0.947
#
#        weight
#         count        mean        std    min    25%    50%     75%    max
# label
# Apple    30.0  161.966667  12.075862  140.0  152.5  164.0  171.50  184.0
# Orange   30.0  123.533333  14.129288  101.0  110.0  124.0  133.75  149.0

# %%
# sphericity>0.845 to wo orange hai
# sphercity agr less hai 0.808 hai  to apple hai...
# weigyt > 149 hai to wo apple hai..
# weight < 140 to wo oranges hai..

# %%
sns.scatterplot(x='sphericity',y='weight',data =df)
plt.show()

# %%
sns.scatterplot(x='sphericity',y='weight',data =df,hue='label')
plt.show()

# %%
X=['sphericty','weight']
Y=['label']

# %%
X
# Out:
# ['sphericty', 'weight']

# %%
Y
# Out:
# ['label']

# %%
X=df[['sphericity','weight']]
Y=df['label']

# %%
X
# Out:
#     sphericity  weight
# 0        0.947     120
# 1        0.917     125
# 2        0.923     110
# 3        0.916     123
# 4        0.943     124
# 5        0.911     130
# 6        0.903     135
# 7        0.918     105
# 8        0.914     132
# 9        0.936     127
# 10       0.829     133
# 11       0.875     134
# 12       0.859     110
# 13       0.849     119
# 14       0.868     106
# 15       0.884     113
# 16       0.872     108
# 17       0.823     132
# 18       0.853     119
# 19       0.808     143
# 20       0.838     101
# 21       0.824     149
# 22       0.894     136
# 23       0.809     141
# 24       0.880     145
# 25       0.834     109
# 26       0.809     108
# 27       0.860     144
# 28       0.870     101
# 29       0.825     124
# 30       0.717     154
# 31       0.711     170
# 32       0.714     164
# 33       0.831     152
# 34       0.721     172
# 35       0.745     181
# 36       0.775     173
# 37       0.791     167
# 38       0.733     184
# ...

# %%
Y
# Out:
# 0     Orange
# 1     Orange
# 2     Orange
# 3     Orange
# 4     Orange
# 5     Orange
# 6     Orange
# 7     Orange
# 8     Orange
# 9     Orange
# 10    Orange
# 11    Orange
# 12    Orange
# 13    Orange
# 14    Orange
# 15    Orange
# 16    Orange
# 17    Orange
# 18    Orange
# 19    Orange
# 20    Orange
# 21    Orange
# 22    Orange
# 23    Orange
# 24    Orange
# 25    Orange
# 26    Orange
# 27    Orange
# 28    Orange
# 29    Orange
# 30     Apple
# 31     Apple
# 32     Apple
# 33     Apple
# 34     Apple
# 35     Apple
# 36     Apple
# 37     Apple
# 38     Apple
# 39     Apple
# 40     Apple
# 41     Apple
# 42     Apple
# 43     Apple
# 44     Apple
# 45     Apple
# 46     Apple
# 47     Apple
# 48     Apple
# 49     Apple
# 50     Apple
# 51     Apple
# 52     Apple
# 53     Apple
# 54     Apple
# 55     Apple
# 56     Apple
# 57     Apple
# 58     Apple
# 59     Apple
# Name: label, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
X_train.shape
# Out:
# (45, 2)

# %%
Y_train.shape
# Out:
# (45,)

# %%
X_test.shape
# Out:
# (15, 2)

# %%
Y_test.shape
# Out:
# (15,)

# %%
Y_train.value_counts()
# Out:
# label
# Orange    25
# Apple     20
# Name: count, dtype: int64

# %%
Y_test.value_counts()
# Out:
# label
# Apple     10
# Orange     5
# Name: count, dtype: int64

# %%
Y_train.value_counts()
# Out:
# label
# Orange    25
# Apple     20
# Name: count, dtype: int64

# %%
plt.scatter(x="sphericity",y="weight",data=df[df.label=="Apple"],c='red',label="Apple")
plt.scatter(x="sphericity",y="weight",data=df[df.label=="Orange"],c='green',label="Orange")
plt.legend()
plt.show() # tghis is ACTUAL DATA K GRAPH HAI

# %%
df
# Out:
#               color  sphericity  weight   label
# 0            Orange       0.947     120  Orange
# 1            Orange       0.917     125  Orange
# 2            Orange       0.923     110  Orange
# 3            Orange       0.916     123  Orange
# 4            Orange       0.943     124  Orange
# 5            Orange       0.911     130  Orange
# 6            Orange       0.903     135  Orange
# 7            Orange       0.918     105  Orange
# 8            Orange       0.914     132  Orange
# 9            Orange       0.936     127  Orange
# 10  Greenish yellow       0.829     133  Orange
# 11  Greenish yellow       0.875     134  Orange
# 12  Greenish yellow       0.859     110  Orange
# 13            Green       0.849     119  Orange
# 14            Green       0.868     106  Orange
# 15  Greenish yellow       0.884     113  Orange
# 16  Greenish yellow       0.872     108  Orange
# 17  Greenish yellow       0.823     132  Orange
# 18            Green       0.853     119  Orange
# ...

# %%
plt.scatter(x="sphericity",y="weight",data=X_train[Y_train=="Apple"],c='red',label="Training Apple")
plt.scatter(x="sphericity",y="weight",data=X_train[Y_train=="Orange"],c='green',label="Training Orange")
plt.legend()
plt.show() # ye TRAINIMG SAMPLES K DATA HAI..

# %%
plt.scatter(x="sphericity",y="weight",data=X_test[Y_test=="Apple"],c='red',label="Testing Apple")
plt.scatter(x="sphericity",y="weight",data=X_test[Y_test=="Orange"],c='green',label="Testing Orange")
plt.legend()
plt.show()

# %%
plt.scatter(x="sphericity",y="weight",data=X_train[Y_train=="Apple"],c='red',label="Training Apple")
plt.scatter(x="sphericity",y="weight",data=X_train[Y_train=="Orange"],c='green',label="Training Orange")
plt.scatter(x="sphericity",y="weight",data=X_test,c='blue',marker="*",label="Testing Apple")
plt.legend()
plt.show() # ye TRAINIMG SAMPLES K DATA HAI..

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
model=DecisionTreeClassifier(criterion="entropy")
model.fit(X_train,Y_train)
plt.figure(figsize=[6,8])
plot_tree(model,feature_names=X.columns,class_names=model.classes_)
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
model=DecisionTreeClassifier(criterion="entropy")
model.fit(X,Y)
plt.figure(figsize=[6,8])
plot_tree(model,feature_names=X.columns,class_names=model.classes_)
plt.show()

# %%
plt.scatter(x="sphericity",y="weight",data=X[Y=="Apple"],c='red',label="Apple")
plt.scatter(x="sphericity",y="weight",data=X[Y=="Orange"],c='green',label="Orange")
plt.plot([0.7,0.95],[138,138],c='black')
plt.plot([0.7,0.95],[150.5,150.5],c='black')
plt.plot([0.796,0.796],[138,150.5],c='black')
plt.legend()
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier,plot_tree
model=DecisionTreeClassifier(criterion="entropy")
model.fit(X_train,Y_train)
plt.figure(figsize=[6,8])
plot_tree(model,feature_names=X.columns,class_names=model.classes_)
plt.show()

# %%
plt.scatter(x="sphericity",y="weight",data=X_train[Y_train=="Apple"],c='red',label="Training Apple")
plt.scatter(x="sphericity",y="weight",data=X_train[Y_train=="Orange"],c='green',label="Training Orange")
#plt.scatter(x="sphericity",y="weight",data=X_test,c='blue',marker="*",label="Testing Apple")
plt.plot([0.7,0.95],[138,138],c='black')
plt.plot([0.7,0.95],[150,150],c='black')
plt.plot([0.796,0.796],[138,150],c='black')
plt.legend()
plt.show()

# %%
model.predict(X_test)
# Out:
# array(['Orange', 'Orange', 'Apple', 'Apple', 'Orange', 'Apple', 'Apple',
#        'Apple', 'Orange', 'Apple', 'Apple', 'Orange', 'Apple', 'Orange',
#        'Apple'], dtype=object)

# %%
Y_test.values
# Out:
# array(['Orange', 'Orange', 'Apple', 'Apple', 'Orange', 'Apple', 'Apple',
#        'Apple', 'Orange', 'Apple', 'Apple', 'Apple', 'Apple', 'Orange',
#        'Apple'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
y_predict2=model.predict(X_test)

# %%
def predict_lable(sphericity,weight):
  if(weight<=138):
    return "Orange"
  elif(weight<=147):
    if(sphericity<=0.796):
      return 'Apple'
    else:
      return "Orange"
  else:
    return "Apple"

# %%
predict_lable(0.711,170)
# Out:
# 'Apple'

# %%
X_test
# Out:
#     sphericity  weight
# 0        0.947     120
# 5        0.911     130
# 36       0.775     173
# 45       0.801     170
# 13       0.849     119
# 54       0.823     167
# 33       0.831     152
# 48       0.710     149
# 12       0.859     110
# 57       0.753     177
# 46       0.803     164
# 50       0.784     142
# 31       0.711     170
# 3        0.916     123
# 52       0.723     165

# %%
[predict_lable(i[0],i[1]) for i in X_test.values]
# Out:
# ['Orange',
#  'Orange',
#  'Apple',
#  'Apple',
#  'Orange',
#  'Apple',
#  'Apple',
#  'Apple',
#  'Orange',
#  'Apple',
#  'Apple',
#  'Apple',
#  'Apple',
#  'Orange',
#  'Apple']

# %%
y_predict1=np.array([predict_lable(i[0],i[1]) for i in X_test.values])
y_predict1
# Out:
# array(['Orange', 'Orange', 'Apple', 'Apple', 'Orange', 'Apple', 'Apple',
#        'Apple', 'Orange', 'Apple', 'Apple', 'Apple', 'Apple', 'Orange',
#        'Apple'], dtype='<U6')

# %%
accuracy_score(Y_test,y_predict2)
# Out:
# 0.9333333333333333

# %%
# WHAT IS ENTROPY?
# ANS:-IMPURITY(HETEROGENEOUS) IN DATA .DISSIMILAR DATA...DISMSIMILAR MEANS (HETROGENEOUS DATA)...SIMILAR DATA MEANS( HOMOGENEOUS DATA)
# RANDOMNESS OF DATA (KUCH BHI DATA AAGYA). WHETEHER THE ALL DATA IN SAME CLASS -> NO RANDOMNESS CALLED
# WHETHER ALL THE DATA IN DIFEERENET CALSS IS CALLED RANDOMNESS..

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
 # WHAT IS INFORMATION GAIN?
 # ANSWER: DROP IN  THE ENTROPY.
 # =P(C)* E(C)..........P(C) IS CALLED FREQUENCY TABLE..........E(C)....ENTROPY OF CLASS....
